# %% [markdown]
# # Question 1. What's the version of Mage we run?

# %% [markdown]
# v0.9.70

# %% [markdown]
# # Question 2: Creating a project
#
# Now let's create a new project. We can call it "homework_03", for example.
#
# How many lines are in the created metadata.yaml file?

# %% [markdown]
# There are 55 line in metadata.yaml file

# %% [markdown]
# # Question 3. Creating a pipeline

# %% [markdown]
# Let's create an ingestion code block.
#
# In this block, we will read the March 2023 Yellow taxi trips data.
#
# How many records did we load?

# %% [markdown]
# There are 3403766 records

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Question 4. Data preparation

# %% [markdown]
# ![Screenshot 2024-05-28 at 18.28.05.png](<attachment:Screenshot 2024-05-28 at 18.28.05.png>)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The size of the data after appyling cleaning is 3316216

# %% [markdown]
# # Question 5. Train a model

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 24.77

# %% [markdown]
# # Qestion 6: Register the model

# %% [markdown]
# ![image.png](attachment:image.png)
